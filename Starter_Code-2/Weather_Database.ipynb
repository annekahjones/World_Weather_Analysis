# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90, high = 90, size = 2000)
lngs = np.random.uniform(low = -180, high = 180, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 787

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a7946c70a0a4583f29394a26fcdcd173

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1
    

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Clouds": city_clouds,
                          "Wind": city_wind,
                          "Weather Description": city_description,
                          "Country": city_country})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 1 | barrow
# Processing Record 3 of Set 1 | ninghai
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | fortuna
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | lagoa
# Processing Record 10 of Set 1 | ahipara
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | les cayes
# Processing Record 13 of Set 1 | armilla
# Processing Record 14 of Set 1 | east london
# Processing Record 15 of Set 1 | vila
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | nome
# Processing Record 18 of Set 1 | riohacha
# Processing Record 19 of Set 1 | ponta do sol
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | hay river
# Processing Record 22 of Set 1 | castro
# Processing Record 23 of Set 1 | cabo san lucas
# Processing Record 24 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 1 | puerto ayora
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | portland
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | san cristobal
# Processing Record 30 of Set 1 | fare
# Processing Record 31 of Set 1 | port elizabeth
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | nanortalik
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | yellowknife
# Processing Record 36 of Set 1 | tasiilaq
# Processing Record 37 of Set 1 | mayo
# Processing Record 38 of Set 1 | manokwari
# Processing Record 39 of Set 1 | arraial do cabo
# Processing Record 40 of Set 1 | kruisfontein
# Processing Record 41 of Set 1 | traverse city
# Processing Record 42 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 43 of Set 1 | lamu
# Processing Record 44 of Set 1 | teeli
# Processing Record 45 of Set 1 | kapaa
# Processing Record 46 of Set 1 | mahebourg
# Processing Record 47 of Set 1 | manzil salim
# Processing Record 48 of Set 1 | basco
# Processing Record 49 of Set 1 | francisco sa
# Processing Record 50 of Set 1 | luzino
# Processing Record 1 of Set 2 | mar del plata
# Processing Record 2 of Set 2 | luganville
# Processing Record 3 of Set 2 | genhe
# Processing Record 4 of Set 2 | margate
# Processing Record 5 of Set 2 | manoel urbano
# Processing Record 6 of Set 2 | bredasdorp
# Processing Record 7 of Set 2 | avarua
# Processing Record 8 of Set 2 | tuktoyaktuk
# Processing Record 9 of Set 2 | tiksi
# Processing Record 10 of Set 2 | atar
# Processing Record 11 of Set 2 | zittau
# Processing Record 12 of Set 2 | ancud
# Processing Record 13 of Set 2 | idenao
# Processing Record 14 of Set 2 | alofi
# Processing Record 15 of Set 2 | hilo
# Processing Record 16 of Set 2 | quatre cocos
# Processing Record 17 of Set 2 | saldanha
# Processing Record 18 of Set 2 | evans
# Processing Record 19 of Set 2 | cape town
# Processing Record 20 of Set 2 | qaanaaq
# Processing Record 21 of Set 2 | los llanos de aridane
# Processing Record 22 of Set 2 | mitu
# Processing Record 23 of Set 2 | yerbogachen
# Processing Record 24 of Set 2 | zyryanka
# Processing Record 25 of Set 2 | zhanatas
# City not found. Skipping...
# Processing Record 26 of Set 2 | narsaq
# Processing Record 27 of Set 2 | dudinka
# Processing Record 28 of Set 2 | cayenne
# Processing Record 29 of Set 2 | longyearbyen
# Processing Record 30 of Set 2 | carnarvon
# Processing Record 31 of Set 2 | jackson
# Processing Record 32 of Set 2 | dikson
# Processing Record 33 of Set 2 | sainte-maxime
# Processing Record 34 of Set 2 | vryburg
# Processing Record 35 of Set 2 | cariati
# Processing Record 36 of Set 2 | clyde river
# Processing Record 37 of Set 2 | butaritari
# Processing Record 38 of Set 2 | sambava
# Processing Record 39 of Set 2 | kodiak
# Processing Record 40 of Set 2 | oksbol
# Processing Record 41 of Set 2 | cartagena
# Processing Record 42 of Set 2 | lloydminster
# Processing Record 43 of Set 2 | biritiba-mirim
# Processing Record 44 of Set 2 | jejuri
# Processing Record 45 of Set 2 | tir pol
# City not found. Skipping...
# Processing Record 46 of Set 2 | tarauaca
# Processing Record 47 of Set 2 | tura
# Processing Record 48 of Set 2 | springbok
# Processing Record 49 of Set 2 | port hardy
# Processing Record 50 of Set 2 | porumbacu de jos
# Processing Record 1 of Set 3 | severnyy
# Processing Record 2 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 3 | hermanus
# Processing Record 4 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 3 | nikolskoye
# Processing Record 6 of Set 3 | nizhniy kuranakh
# Processing Record 7 of Set 3 | ushtobe
# Processing Record 8 of Set 3 | gurgan
# City not found. Skipping...
# Processing Record 9 of Set 3 | ketchikan
# Processing Record 10 of Set 3 | upernavik
# Processing Record 11 of Set 3 | sorkjosen
# Processing Record 12 of Set 3 | henties bay
# Processing Record 13 of Set 3 | belyy yar
# Processing Record 14 of Set 3 | karratha
# Processing Record 15 of Set 3 | kirkenes
# Processing Record 16 of Set 3 | seoul
# Processing Record 17 of Set 3 | grindavik
# Processing Record 18 of Set 3 | antofagasta
# Processing Record 19 of Set 3 | hithadhoo
# Processing Record 20 of Set 3 | shestakovo
# Processing Record 21 of Set 3 | lushunkou
# City not found. Skipping...
# Processing Record 22 of Set 3 | coos bay
# Processing Record 23 of Set 3 | marystown
# Processing Record 24 of Set 3 | mumford
# Processing Record 25 of Set 3 | lalmohan
# Processing Record 26 of Set 3 | klaksvik
# Processing Record 27 of Set 3 | shimoda
# Processing Record 28 of Set 3 | iqaluit
# Processing Record 29 of Set 3 | adrar
# Processing Record 30 of Set 3 | lorengau
# Processing Record 31 of Set 3 | torbay
# Processing Record 32 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 33 of Set 3 | prince rupert
# Processing Record 34 of Set 3 | thompson
# Processing Record 35 of Set 3 | xingtai
# Processing Record 36 of Set 3 | bardiyah
# Processing Record 37 of Set 3 | nouadhibou
# Processing Record 38 of Set 3 | sembabule
# Processing Record 39 of Set 3 | bengkulu
# Processing Record 40 of Set 3 | sinnamary
# Processing Record 41 of Set 3 | mukhen
# Processing Record 42 of Set 3 | bethel
# Processing Record 43 of Set 3 | cidreira
# Processing Record 44 of Set 3 | ukiah
# Processing Record 45 of Set 3 | korla
# Processing Record 46 of Set 3 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 47 of Set 3 | goshen
# Processing Record 48 of Set 3 | westport
# Processing Record 49 of Set 3 | pamyat parizhskoy kommuny
# Processing Record 50 of Set 3 | bilecik
# Processing Record 1 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 4 | aklavik
# Processing Record 3 of Set 4 | lisala
# Processing Record 4 of Set 4 | kaitangata
# Processing Record 5 of Set 4 | vila velha
# Processing Record 6 of Set 4 | arona
# Processing Record 7 of Set 4 | ikom
# Processing Record 8 of Set 4 | price
# Processing Record 9 of Set 4 | vanimo
# Processing Record 10 of Set 4 | faya
# Processing Record 11 of Set 4 | iralaya
# Processing Record 12 of Set 4 | zastron
# Processing Record 13 of Set 4 | hobart
# Processing Record 14 of Set 4 | tezu
# Processing Record 15 of Set 4 | padang
# Processing Record 16 of Set 4 | port alfred
# Processing Record 17 of Set 4 | veinticinco de diciembre
# Processing Record 18 of Set 4 | airai
# Processing Record 19 of Set 4 | terny
# Processing Record 20 of Set 4 | georgetown
# Processing Record 21 of Set 4 | ugoofaaru
# Processing Record 22 of Set 4 | saint-pierre
# Processing Record 23 of Set 4 | hermitage
# Processing Record 24 of Set 4 | phan thiet
# Processing Record 25 of Set 4 | middlebury
# Processing Record 26 of Set 4 | saint george
# Processing Record 27 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 4 | yulara
# Processing Record 29 of Set 4 | rosarito
# Processing Record 30 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 4 | kaeo
# Processing Record 32 of Set 4 | guerrero negro
# Processing Record 33 of Set 4 | rayong
# Processing Record 34 of Set 4 | skegness
# Processing Record 35 of Set 4 | tanout
# Processing Record 36 of Set 4 | marawi
# Processing Record 37 of Set 4 | pangnirtung
# Processing Record 38 of Set 4 | general roca
# Processing Record 39 of Set 4 | nyanguge
# Processing Record 40 of Set 4 | labuhan
# Processing Record 41 of Set 4 | bosaso
# Processing Record 42 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 4 | kavieng
# Processing Record 45 of Set 4 | ilulissat
# Processing Record 46 of Set 4 | walvis bay
# Processing Record 47 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 4 | victoria
# Processing Record 49 of Set 4 | sao sebastiao
# Processing Record 50 of Set 4 | santiago
# Processing Record 1 of Set 5 | baker city
# Processing Record 2 of Set 5 | muriwai beach
# Processing Record 3 of Set 5 | nidzica
# Processing Record 4 of Set 5 | cherskiy
# Processing Record 5 of Set 5 | provideniya
# Processing Record 6 of Set 5 | hirara
# Processing Record 7 of Set 5 | pevek
# Processing Record 8 of Set 5 | chuy
# Processing Record 9 of Set 5 | huambo
# Processing Record 10 of Set 5 | geraldton
# Processing Record 11 of Set 5 | san patricio
# Processing Record 12 of Set 5 | xai-xai
# Processing Record 13 of Set 5 | omboue
# Processing Record 14 of Set 5 | ribeira grande
# Processing Record 15 of Set 5 | caravelas
# Processing Record 16 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 5 | norman wells
# Processing Record 19 of Set 5 | sur
# Processing Record 20 of Set 5 | ostrovnoy
# Processing Record 21 of Set 5 | alyangula
# Processing Record 22 of Set 5 | hasaki
# Processing Record 23 of Set 5 | ambunti
# Processing Record 24 of Set 5 | soto la marina
# Processing Record 25 of Set 5 | codrington
# Processing Record 26 of Set 5 | bilma
# Processing Record 27 of Set 5 | rafai
# Processing Record 28 of Set 5 | french harbor
# Processing Record 29 of Set 5 | barao de melgaco
# Processing Record 30 of Set 5 | acurenam
# Processing Record 31 of Set 5 | marathokambos
# City not found. Skipping...
# Processing Record 32 of Set 5 | esmeralda
# Processing Record 33 of Set 5 | akashi
# Processing Record 34 of Set 5 | tecoanapa
# Processing Record 35 of Set 5 | abu zabad
# Processing Record 36 of Set 5 | muros
# Processing Record 37 of Set 5 | ovsyanka
# Processing Record 38 of Set 5 | tuy hoa
# Processing Record 39 of Set 5 | copiapo
# Processing Record 40 of Set 5 | kota
# Processing Record 41 of Set 5 | naze
# Processing Record 42 of Set 5 | tambura
# Processing Record 43 of Set 5 | morgan city
# Processing Record 44 of Set 5 | morada nova
# Processing Record 45 of Set 5 | oistins
# Processing Record 46 of Set 5 | mangrol
# Processing Record 47 of Set 5 | helong
# Processing Record 48 of Set 5 | ranot
# Processing Record 49 of Set 5 | santa maria
# Processing Record 50 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 6 | fougamou
# Processing Record 2 of Set 6 | port-gentil
# Processing Record 3 of Set 6 | ranong
# Processing Record 4 of Set 6 | sao filipe
# Processing Record 5 of Set 6 | souillac
# Processing Record 6 of Set 6 | krasnoselkup
# Processing Record 7 of Set 6 | kirsanov
# Processing Record 8 of Set 6 | te anau
# Processing Record 9 of Set 6 | chenghai
# Processing Record 10 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 11 of Set 6 | healdsburg
# Processing Record 12 of Set 6 | panguipulli
# Processing Record 13 of Set 6 | coihaique
# Processing Record 14 of Set 6 | lacombe
# Processing Record 15 of Set 6 | millinocket
# Processing Record 16 of Set 6 | saint-philippe
# Processing Record 17 of Set 6 | nago
# Processing Record 18 of Set 6 | chumikan
# Processing Record 19 of Set 6 | hami
# Processing Record 20 of Set 6 | alice springs
# Processing Record 21 of Set 6 | kenai
# Processing Record 22 of Set 6 | kandrian
# Processing Record 23 of Set 6 | magadi
# Processing Record 24 of Set 6 | severo-kurilsk
# Processing Record 25 of Set 6 | izumo
# Processing Record 26 of Set 6 | katherine
# Processing Record 27 of Set 6 | chokurdakh
# Processing Record 28 of Set 6 | katsuura
# Processing Record 29 of Set 6 | serov
# Processing Record 30 of Set 6 | zaysan
# Processing Record 31 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 32 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 6 | udachnyy
# Processing Record 34 of Set 6 | srednekolymsk
# Processing Record 35 of Set 6 | talnakh
# Processing Record 36 of Set 6 | guaruja
# Processing Record 37 of Set 6 | paamiut
# Processing Record 38 of Set 6 | saskylakh
# Processing Record 39 of Set 6 | lavrentiya
# Processing Record 40 of Set 6 | mercedes
# Processing Record 41 of Set 6 | anshan
# Processing Record 42 of Set 6 | praia da vitoria
# Processing Record 43 of Set 6 | angoram
# Processing Record 44 of Set 6 | sao joao da barra
# Processing Record 45 of Set 6 | matagami
# Processing Record 46 of Set 6 | brae
# Processing Record 47 of Set 6 | sobolevo
# Processing Record 48 of Set 6 | sampit
# Processing Record 49 of Set 6 | khatanga
# Processing Record 50 of Set 6 | karasjok
# Processing Record 1 of Set 7 | kimbe
# Processing Record 2 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 7 | rogers
# Processing Record 4 of Set 7 | lebu
# Processing Record 5 of Set 7 | paciran
# Processing Record 6 of Set 7 | vestmannaeyjar
# Processing Record 7 of Set 7 | port-cartier
# Processing Record 8 of Set 7 | kalat
# Processing Record 9 of Set 7 | svetlaya
# Processing Record 10 of Set 7 | poso
# Processing Record 11 of Set 7 | banepa
# Processing Record 12 of Set 7 | new norfolk
# Processing Record 13 of Set 7 | campeche
# Processing Record 14 of Set 7 | imeni poliny osipenko
# Processing Record 15 of Set 7 | gat
# Processing Record 16 of Set 7 | venado tuerto
# Processing Record 17 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 18 of Set 7 | gizo
# Processing Record 19 of Set 7 | buqayq
# City not found. Skipping...
# Processing Record 20 of Set 7 | barsovo
# Processing Record 21 of Set 7 | qaqortoq
# Processing Record 22 of Set 7 | labytnangi
# Processing Record 23 of Set 7 | bonga
# Processing Record 24 of Set 7 | abu samrah
# Processing Record 25 of Set 7 | olafsvik
# Processing Record 26 of Set 7 | bandundu
# Processing Record 27 of Set 7 | tottori
# Processing Record 28 of Set 7 | bull savanna
# Processing Record 29 of Set 7 | yeppoon
# Processing Record 30 of Set 7 | dali
# Processing Record 31 of Set 7 | cabras
# Processing Record 32 of Set 7 | richards bay
# Processing Record 33 of Set 7 | maniitsoq
# Processing Record 34 of Set 7 | kafanchan
# Processing Record 35 of Set 7 | okha
# Processing Record 36 of Set 7 | ishim
# Processing Record 37 of Set 7 | mount gambier
# Processing Record 38 of Set 7 | huancavelica
# Processing Record 39 of Set 7 | collie
# Processing Record 40 of Set 7 | pacifica
# Processing Record 41 of Set 7 | itarema
# Processing Record 42 of Set 7 | amapa
# Processing Record 43 of Set 7 | la peca
# Processing Record 44 of Set 7 | hauterive
# Processing Record 45 of Set 7 | juneau
# Processing Record 46 of Set 7 | vao
# Processing Record 47 of Set 7 | grand-santi
# Processing Record 48 of Set 7 | san quintin
# Processing Record 49 of Set 7 | bom jesus
# Processing Record 50 of Set 7 | gushikawa
# Processing Record 1 of Set 8 | sembe
# Processing Record 2 of Set 8 | aguimes
# Processing Record 3 of Set 8 | piranshahr
# Processing Record 4 of Set 8 | mtwara
# Processing Record 5 of Set 8 | sunrise manor
# Processing Record 6 of Set 8 | strezhevoy
# Processing Record 7 of Set 8 | high level
# Processing Record 8 of Set 8 | verkhnevilyuysk
# Processing Record 9 of Set 8 | bac lieu
# Processing Record 10 of Set 8 | hornepayne
# Processing Record 11 of Set 8 | takoradi
# Processing Record 12 of Set 8 | remanso
# Processing Record 13 of Set 8 | mareeba
# Processing Record 14 of Set 8 | maryville
# Processing Record 15 of Set 8 | komsomolskiy
# Processing Record 16 of Set 8 | misratah
# Processing Record 17 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 18 of Set 8 | svetlogorsk
# Processing Record 19 of Set 8 | sangueya
# Processing Record 20 of Set 8 | raudeberg
# Processing Record 21 of Set 8 | acapulco
# Processing Record 22 of Set 8 | pozzallo
# Processing Record 23 of Set 8 | sitka
# Processing Record 24 of Set 8 | puke
# Processing Record 25 of Set 8 | princeton
# Processing Record 26 of Set 8 | port blair
# Processing Record 27 of Set 8 | tabulbah
# City not found. Skipping...
# Processing Record 28 of Set 8 | jawar
# Processing Record 29 of Set 8 | felipe carrillo puerto
# Processing Record 30 of Set 8 | la ronge
# Processing Record 31 of Set 8 | saint-augustin
# Processing Record 32 of Set 8 | pachino
# Processing Record 33 of Set 8 | bandar-e anzali
# Processing Record 34 of Set 8 | tongchuan
# Processing Record 35 of Set 8 | evensk
# Processing Record 36 of Set 8 | rockland
# Processing Record 37 of Set 8 | bajo baudo
# City not found. Skipping...
# Processing Record 38 of Set 8 | tiarei
# Processing Record 39 of Set 8 | akureyri
# Processing Record 40 of Set 8 | nevel
# Processing Record 41 of Set 8 | bouguenais
# Processing Record 42 of Set 8 | tumut
# Processing Record 43 of Set 8 | davila
# Processing Record 44 of Set 8 | stoyba
# City not found. Skipping...
# Processing Record 45 of Set 8 | luderitz
# Processing Record 46 of Set 8 | omsukchan
# Processing Record 47 of Set 8 | caluquembe
# Processing Record 48 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 8 | bathsheba
# Processing Record 50 of Set 8 | gedo
# Processing Record 1 of Set 9 | isla mujeres
# Processing Record 2 of Set 9 | koszalin
# Processing Record 3 of Set 9 | manicore
# Processing Record 4 of Set 9 | gamba
# Processing Record 5 of Set 9 | rio grande
# Processing Record 6 of Set 9 | hofn
# Processing Record 7 of Set 9 | oranjemund
# Processing Record 8 of Set 9 | narasannapeta
# Processing Record 9 of Set 9 | egvekinot
# Processing Record 10 of Set 9 | beyneu
# Processing Record 11 of Set 9 | laguna
# Processing Record 12 of Set 9 | ust-nera
# Processing Record 13 of Set 9 | birao
# Processing Record 14 of Set 9 | maputo
# Processing Record 15 of Set 9 | puerto narino
# Processing Record 16 of Set 9 | toftir
# City not found. Skipping...
# Processing Record 17 of Set 9 | castelo branco
# Processing Record 18 of Set 9 | baie-comeau
# Processing Record 19 of Set 9 | buchanan
# Processing Record 20 of Set 9 | kota kinabalu
# Processing Record 21 of Set 9 | houma
# Processing Record 22 of Set 9 | otane
# Processing Record 23 of Set 9 | presidencia roque saenz pena
# Processing Record 24 of Set 9 | laiagam
# City not found. Skipping...
# Processing Record 25 of Set 9 | sitio novo do tocantins
# Processing Record 26 of Set 9 | honggang
# Processing Record 27 of Set 9 | moerai
# Processing Record 28 of Set 9 | lithgow
# Processing Record 29 of Set 9 | tingo maria
# Processing Record 30 of Set 9 | black forest
# Processing Record 31 of Set 9 | marienburg
# Processing Record 32 of Set 9 | leningradskiy
# Processing Record 33 of Set 9 | lata
# Processing Record 34 of Set 9 | chardara
# Processing Record 35 of Set 9 | arlit
# Processing Record 36 of Set 9 | banyo
# Processing Record 37 of Set 9 | phalombe
# Processing Record 38 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 39 of Set 9 | honiara
# Processing Record 40 of Set 9 | kavaratti
# Processing Record 41 of Set 9 | daru
# Processing Record 42 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 43 of Set 9 | niagara falls
# Processing Record 44 of Set 9 | meadow lake
# Processing Record 45 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 46 of Set 9 | brigantine
# Processing Record 47 of Set 9 | petauke
# Processing Record 48 of Set 9 | champerico
# Processing Record 49 of Set 9 | dawei
# Processing Record 50 of Set 9 | hrubieszow
# Processing Record 1 of Set 10 | lufilufi
# Processing Record 2 of Set 10 | kaluga
# Processing Record 3 of Set 10 | saint anthony
# Processing Record 4 of Set 10 | faanui
# Processing Record 5 of Set 10 | cuamba
# Processing Record 6 of Set 10 | bogalusa
# Processing Record 7 of Set 10 | eureka
# Processing Record 8 of Set 10 | ngunguru
# Processing Record 9 of Set 10 | tautira
# Processing Record 10 of Set 10 | san rafael
# Processing Record 11 of Set 10 | yar-sale
# Processing Record 12 of Set 10 | port hedland
# Processing Record 13 of Set 10 | christchurch
# Processing Record 14 of Set 10 | novouzensk
# Processing Record 15 of Set 10 | beauceville
# Processing Record 16 of Set 10 | krasnoyarskiy
# Processing Record 17 of Set 10 | asosa
# Processing Record 18 of Set 10 | sangar
# Processing Record 19 of Set 10 | micheweni
# Processing Record 20 of Set 10 | urengoy
# Processing Record 21 of Set 10 | nadvoitsy
# Processing Record 22 of Set 10 | black river
# Processing Record 23 of Set 10 | jiexiu
# Processing Record 24 of Set 10 | gorontalo
# Processing Record 25 of Set 10 | dunedin
# Processing Record 26 of Set 10 | kahului
# Processing Record 27 of Set 10 | gimli
# Processing Record 28 of Set 10 | huilong
# Processing Record 29 of Set 10 | bulawayo
# Processing Record 30 of Set 10 | kataysk
# Processing Record 31 of Set 10 | bonthe
# Processing Record 32 of Set 10 | ixtapa
# Processing Record 33 of Set 10 | pochutla
# Processing Record 34 of Set 10 | cedar city
# Processing Record 35 of Set 10 | thinadhoo
# Processing Record 36 of Set 10 | stonewall
# Processing Record 37 of Set 10 | dukat
# Processing Record 38 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 10 | flinders
# Processing Record 40 of Set 10 | baykit
# Processing Record 41 of Set 10 | constitucion
# Processing Record 42 of Set 10 | monterey
# Processing Record 43 of Set 10 | cockburn town
# Processing Record 44 of Set 10 | kiama
# Processing Record 45 of Set 10 | mitsamiouli
# Processing Record 46 of Set 10 | maragogi
# Processing Record 47 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 48 of Set 10 | jacareacanga
# Processing Record 49 of Set 10 | nuuk
# Processing Record 50 of Set 10 | canton
# Processing Record 1 of Set 11 | san luis
# Processing Record 2 of Set 11 | dongsheng
# Processing Record 3 of Set 11 | dixon
# Processing Record 4 of Set 11 | nelson bay
# Processing Record 5 of Set 11 | luena
# Processing Record 6 of Set 11 | urfa
# City not found. Skipping...
# Processing Record 7 of Set 11 | alugan
# Processing Record 8 of Set 11 | port lincoln
# Processing Record 9 of Set 11 | ambon
# Processing Record 10 of Set 11 | vila franca do campo
# Processing Record 11 of Set 11 | canico
# Processing Record 12 of Set 11 | kuna
# Processing Record 13 of Set 11 | mantua
# Processing Record 14 of Set 11 | whitehorse
# Processing Record 15 of Set 11 | susuman
# Processing Record 16 of Set 11 | pyay
# Processing Record 17 of Set 11 | mao
# Processing Record 18 of Set 11 | yumen
# Processing Record 19 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 11 | kismayo
# Processing Record 21 of Set 11 | necochea
# Processing Record 22 of Set 11 | mildura
# Processing Record 23 of Set 11 | sovetskiy
# Processing Record 24 of Set 11 | avera
# Processing Record 25 of Set 11 | ponta delgada
# Processing Record 26 of Set 11 | jaru
# Processing Record 27 of Set 11 | noyabrsk
# Processing Record 28 of Set 11 | bedford
# Processing Record 29 of Set 11 | mehamn
# Processing Record 30 of Set 11 | moron
# Processing Record 31 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 32 of Set 11 | baruun-urt
# Processing Record 33 of Set 11 | chihuahua
# Processing Record 34 of Set 11 | nushki
# Processing Record 35 of Set 11 | upata
# Processing Record 36 of Set 11 | sananduva
# Processing Record 37 of Set 11 | paducah
# Processing Record 38 of Set 11 | dasoguz
# Processing Record 39 of Set 11 | manzil jamil
# City not found. Skipping...
# Processing Record 40 of Set 11 | bambous virieux
# Processing Record 41 of Set 11 | bulembu
# Processing Record 42 of Set 11 | bokoro
# Processing Record 43 of Set 11 | iringa
# Processing Record 44 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 45 of Set 11 | yenagoa
# Processing Record 46 of Set 11 | turayf
# Processing Record 47 of Set 11 | trairi
# Processing Record 48 of Set 11 | nishihara
# Processing Record 49 of Set 11 | salinopolis
# Processing Record 50 of Set 11 | borovskoy
# Processing Record 1 of Set 12 | vitim
# Processing Record 2 of Set 12 | badulla
# Processing Record 3 of Set 12 | barranca
# Processing Record 4 of Set 12 | pacific grove
# Processing Record 5 of Set 12 | corinto
# Processing Record 6 of Set 12 | keetmanshoop
# Processing Record 7 of Set 12 | san carlos de bariloche
# Processing Record 8 of Set 12 | marsh harbour
# Processing Record 9 of Set 12 | tabuk
# Processing Record 10 of Set 12 | buala
# Processing Record 11 of Set 12 | mount isa
# Processing Record 12 of Set 12 | wobulenzi
# Processing Record 13 of Set 12 | iglesias
# Processing Record 14 of Set 12 | navolato
# Processing Record 15 of Set 12 | mongu
# Processing Record 16 of Set 12 | bousso
# Processing Record 17 of Set 12 | skibbereen
# Processing Record 18 of Set 12 | abonnema
# Processing Record 19 of Set 12 | stabat
# Processing Record 20 of Set 12 | chicama
# Processing Record 21 of Set 12 | bandarbeyla
# Processing Record 22 of Set 12 | shelburne
# Processing Record 23 of Set 12 | itapirapua
# Processing Record 24 of Set 12 | gavle
# Processing Record 25 of Set 12 | bara
# Processing Record 26 of Set 12 | guajara-mirim
# City not found. Skipping...
# Processing Record 27 of Set 12 | bossier city
# Processing Record 28 of Set 12 | dingle
# Processing Record 29 of Set 12 | flin flon
# Processing Record 30 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 12 | manado
# Processing Record 32 of Set 12 | fairbanks
# Processing Record 33 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 34 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 12 | altamira
# Processing Record 36 of Set 12 | jinhua
# Processing Record 37 of Set 12 | filingue
# Processing Record 38 of Set 12 | cascais
# Processing Record 39 of Set 12 | petropavlovskaya
# Processing Record 40 of Set 12 | rokytne
# Processing Record 41 of Set 12 | ribeira brava
# Processing Record 42 of Set 12 | bilibino
# Processing Record 43 of Set 12 | sorong
# Processing Record 44 of Set 12 | puerto carreno
# Processing Record 45 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 12 | beian
# Processing Record 47 of Set 12 | arman
# Processing Record 48 of Set 12 | aripuana
# Processing Record 49 of Set 12 | zhigansk
# Processing Record 50 of Set 12 | lethbridge
# Processing Record 1 of Set 13 | manavalakurichi
# Processing Record 2 of Set 13 | coquimbo
# Processing Record 3 of Set 13 | cadillac
# Processing Record 4 of Set 13 | umea
# Processing Record 5 of Set 13 | ilorin
# Processing Record 6 of Set 13 | neepawa
# Processing Record 7 of Set 13 | camacha
# Processing Record 8 of Set 13 | eldikan
# City not found. Skipping...
# Processing Record 9 of Set 13 | namatanai
# Processing Record 10 of Set 13 | dori
# Processing Record 11 of Set 13 | hamilton
# Processing Record 12 of Set 13 | bud
# Processing Record 13 of Set 13 | gorin
# Processing Record 14 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 13 | obo
# Processing Record 16 of Set 13 | kampot
# Processing Record 17 of Set 13 | north bend
# Processing Record 18 of Set 13 | batagay-alyta
# Processing Record 19 of Set 13 | anadyr
# Processing Record 20 of Set 13 | kashan
# Processing Record 21 of Set 13 | suntar
# Processing Record 22 of Set 13 | ca mau
# Processing Record 23 of Set 13 | mana
# Processing Record 24 of Set 13 | isangel
# Processing Record 25 of Set 13 | mayya
# Processing Record 26 of Set 13 | northam
# Processing Record 27 of Set 13 | ayan
# Processing Record 28 of Set 13 | port macquarie
# Processing Record 29 of Set 13 | verden
# Processing Record 30 of Set 13 | belaya gora
# Processing Record 31 of Set 13 | mackenzie
# Processing Record 32 of Set 13 | bastia
# Processing Record 33 of Set 13 | rabak
# Processing Record 34 of Set 13 | bubaque
# Processing Record 35 of Set 13 | lephepe
# City not found. Skipping...
# Processing Record 36 of Set 13 | capoterra
# Processing Record 37 of Set 13 | maroantsetra
# Processing Record 38 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 39 of Set 13 | qena
# Processing Record 40 of Set 13 | gagarin
# Processing Record 41 of Set 13 | maracaju
# Processing Record 42 of Set 13 | meridian
# Processing Record 43 of Set 13 | iracoubo
# Processing Record 44 of Set 13 | bowen
# Processing Record 45 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 13 | teneguiban
# City not found. Skipping...
# Processing Record 47 of Set 13 | shihezi
# Processing Record 48 of Set 13 | vysokogornyy
# Processing Record 49 of Set 13 | aqtobe
# Processing Record 50 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 14 | ilhabela
# Processing Record 2 of Set 14 | lodja
# Processing Record 3 of Set 14 | jablah
# Processing Record 4 of Set 14 | inirida
# Processing Record 5 of Set 14 | izhma
# Processing Record 6 of Set 14 | magadan
# Processing Record 7 of Set 14 | shubarkuduk
# Processing Record 8 of Set 14 | bougouni
# Processing Record 9 of Set 14 | lompoc
# Processing Record 10 of Set 14 | santiago del estero
# Processing Record 11 of Set 14 | kibaya
# Processing Record 12 of Set 14 | sioux lookout
# Processing Record 13 of Set 14 | carbonia
# Processing Record 14 of Set 14 | jinxiang
# Processing Record 15 of Set 14 | alihe
# Processing Record 16 of Set 14 | abha
# Processing Record 17 of Set 14 | tarbolton
# Processing Record 18 of Set 14 | bababe
# City not found. Skipping...
# Processing Record 19 of Set 14 | kambia
# Processing Record 20 of Set 14 | jumla
# Processing Record 21 of Set 14 | tirumullaivasal
# Processing Record 22 of Set 14 | odweyne
# Processing Record 23 of Set 14 | galveston
# Processing Record 24 of Set 14 | nizhniy odes
# Processing Record 25 of Set 14 | mopti
# Processing Record 26 of Set 14 | erzin
# Processing Record 27 of Set 14 | marathon
# Processing Record 28 of Set 14 | burica
# City not found. Skipping...
# Processing Record 29 of Set 14 | machali
# Processing Record 30 of Set 14 | saint-joseph
# Processing Record 31 of Set 14 | matara
# Processing Record 32 of Set 14 | college
# Processing Record 33 of Set 14 | makakilo city
# Processing Record 34 of Set 14 | shahreza
# Processing Record 35 of Set 14 | teknaf
# Processing Record 36 of Set 14 | smithers
# Processing Record 37 of Set 14 | cuauhtemoc
# Processing Record 38 of Set 14 | goure
# Processing Record 39 of Set 14 | prado
# Processing Record 40 of Set 14 | sola
# Processing Record 41 of Set 14 | aykhal
# Processing Record 42 of Set 14 | ewa beach
# Processing Record 43 of Set 14 | vardo
# Processing Record 44 of Set 14 | la orilla
# Processing Record 45 of Set 14 | dillon
# Processing Record 46 of Set 14 | tandalti
# Processing Record 47 of Set 14 | grand gaube
# Processing Record 48 of Set 14 | fort nelson
# Processing Record 49 of Set 14 | amahai
# Processing Record 50 of Set 14 | serenje
# Processing Record 1 of Set 15 | luanda
# Processing Record 2 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 15 | lugoba
# Processing Record 4 of Set 15 | sakaiminato
# Processing Record 5 of Set 15 | puerto escondido
# Processing Record 6 of Set 15 | touros
# Processing Record 7 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 8 of Set 15 | ulaangom
# Processing Record 9 of Set 15 | waingapu
# Processing Record 10 of Set 15 | the pas
# Processing Record 11 of Set 15 | pisco
# Processing Record 12 of Set 15 | show low
# Processing Record 13 of Set 15 | beringovskiy
# Processing Record 14 of Set 15 | severo-yeniseyskiy
# Processing Record 15 of Set 15 | sattahip
# Processing Record 16 of Set 15 | butler
# Processing Record 17 of Set 15 | turukhansk
# Processing Record 18 of Set 15 | sibolga
# Processing Record 19 of Set 15 | lakheri
# Processing Record 20 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 15 | sukhobuzimskoye
# Processing Record 22 of Set 15 | nieuw amsterdam
# Processing Record 23 of Set 15 | maceio
# Processing Record 24 of Set 15 | hatta
# Processing Record 25 of Set 15 | taoudenni
# Processing Record 26 of Set 15 | griffith
# Processing Record 27 of Set 15 | toccoa
# Processing Record 28 of Set 15 | husavik
# Processing Record 29 of Set 15 | torbat-e jam
# Processing Record 30 of Set 15 | wanning
# Processing Record 31 of Set 15 | jabinyanah
# Processing Record 32 of Set 15 | ballyshannon
# Processing Record 33 of Set 15 | biak
# Processing Record 34 of Set 15 | kirakira
# Processing Record 35 of Set 15 | carballo
# Processing Record 36 of Set 15 | beboto
# Processing Record 37 of Set 15 | tuatapere
# Processing Record 38 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 39 of Set 15 | kerema
# Processing Record 40 of Set 15 | bousse
# Processing Record 41 of Set 15 | pag
# Processing Record 42 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 43 of Set 15 | pasni
# Processing Record 44 of Set 15 | half moon bay
# Processing Record 45 of Set 15 | dodge city
# Processing Record 46 of Set 15 | chipinge
# Processing Record 47 of Set 15 | esso
# Processing Record 48 of Set 15 | shuya
# Processing Record 49 of Set 15 | deep river
# Processing Record 50 of Set 15 | belogradcik
# City not found. Skipping...
# Processing Record 1 of Set 16 | mahon
# Processing Record 2 of Set 16 | malisbong
# City not found. Skipping...
# Processing Record 3 of Set 16 | rabo de peixe
# Processing Record 4 of Set 16 | teguldet
# Processing Record 5 of Set 16 | chunoyar
# Processing Record 6 of Set 16 | tabialan
# City not found. Skipping...
# Processing Record 7 of Set 16 | port shepstone
# Processing Record 8 of Set 16 | puerto del rosario
# Processing Record 9 of Set 16 | porto novo
# Processing Record 10 of Set 16 | paita
# Processing Record 11 of Set 16 | la rioja
# Processing Record 12 of Set 16 | springfield
# Processing Record 13 of Set 16 | tarudant
# City not found. Skipping...
# Processing Record 14 of Set 16 | sataua
# City not found. Skipping...
# Processing Record 15 of Set 16 | miles city
# Processing Record 16 of Set 16 | holme
# Processing Record 17 of Set 16 | nemuro
# Processing Record 18 of Set 16 | orativ
# Processing Record 19 of Set 16 | puerto colombia
# Processing Record 20 of Set 16 | hovd
# Processing Record 21 of Set 16 | isiro
# Processing Record 22 of Set 16 | neuquen
# Processing Record 23 of Set 16 | haines junction
# Processing Record 24 of Set 16 | mahadday weyne
# City not found. Skipping...
# Processing Record 25 of Set 16 | forbes
# Processing Record 26 of Set 16 | viedma
# Processing Record 27 of Set 16 | mwene-ditu
# Processing Record 28 of Set 16 | jardim
# Processing Record 29 of Set 16 | babanusah
# City not found. Skipping...
# Processing Record 30 of Set 16 | gazanjyk
# Processing Record 31 of Set 16 | pandan
# Processing Record 32 of Set 16 | tuma
# Processing Record 33 of Set 16 | bodden town
# Processing Record 34 of Set 16 | calvinia
# Processing Record 35 of Set 16 | tanshui
# City not found. Skipping...
# Processing Record 36 of Set 16 | tamiahua
# Processing Record 37 of Set 16 | lewiston
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 716

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Clouds   Wind  \
# 0         Barrow  71.2906 -156.7887      8.62        78     100  16.11
# 1        Ninghai  29.2892  121.4247     50.65        65      16   5.66
# 2         Atuona  -9.8000 -139.0333     78.64        73      10  18.97
# 3        Ushuaia -54.8000  -68.3000     38.86        87      75   3.44
# 4        Fortuna  40.5982 -124.1573     52.14        71     100  17.27
# ..           ...      ...       ...       ...       ...     ...    ...
# 711         Tuma  55.1480   40.5537     22.93        89     100  10.65
# 712  Bodden Town  19.2833  -81.2500     77.94        82       1   3.00
# 713     Calvinia -31.4707   19.7760     64.90        56     100   9.60
# 714     Tamiahua  21.2667  -97.4500     69.98        89       0   7.61
# 715     Lewiston  44.1003  -70.2148     37.38        97     100   2.95
#
#     Weather Description Country
# 0            light snow      US
# 1            few clouds      CN
# 2             clear sky      PF
# 3            light rain      AR
# 4       overcast clouds      US
# ..                  ...     ...
# 711     overcast clouds      RU
# 712           clear sky      KY
# 713     overcast clouds      ZA
# 714           clear sky      MX
# 715          light snow      US
#
# [716 rows x 9 columns]

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Clouds', 'Wind',
#        'Weather Description', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Clouds", "Wind", "Weather Description"]
new_order
city_data_df = city_data_df[new_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Clouds   Wind  \
# 0        Barrow      US  71.2906 -156.7887      8.62        78     100  16.11
# 1       Ninghai      CN  29.2892  121.4247     50.65        65      16   5.66
# 2        Atuona      PF  -9.8000 -139.0333     78.64        73      10  18.97
# 3       Ushuaia      AR -54.8000  -68.3000     38.86        87      75   3.44
# 4       Fortuna      US  40.5982 -124.1573     52.14        71     100  17.27
# 5         Vaini      TO -21.2000 -175.2000     77.16        94     100   3.44
# 6         Lagoa      PT  39.0500  -27.9833     59.61        78      10  20.65
# 7       Ahipara      NZ -35.1667  173.1667     68.20        97     100  13.69
# 8  Punta Arenas      CL -53.1500  -70.9167     50.11        93      40  39.12
# 9     Les Cayes      HT  18.2000  -73.7500     71.20        85       4   5.73
#
#   Weather Description
# 0          light snow
# 1          few clouds
# 2           clear sky
# 3          light rain
# 4     overcast clouds
# 5       moderate rain
# 6           clear sky
# 7     overcast clouds
# 8          light rain
# 9           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Clouds                   int64
# Wind                   float64
# Weather Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label = "City_ID")
